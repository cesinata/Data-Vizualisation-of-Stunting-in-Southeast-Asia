# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Stunting

# %%
st = pd.read_excel('/content/drive/MyDrive/SIC_2022_CELERA/221 stunting.xlsx')
st
# Out:
#     Goal  Target Indicator   SeriesCode  \
# 0    2.0     2.2     2.2.1  SH_STA_STNT
# 1    2.0     2.2     2.2.1  SH_STA_STNT
# 2    2.0     2.2     2.2.1  SH_STA_STNT
# 3    2.0     2.2     2.2.1  SH_STA_STNT
# 4    2.0     2.2     2.2.1  SH_STA_STNT
# 5    2.0     2.2     2.2.1  SH_STA_STNT
# 6    2.0     2.2     2.2.1  SH_STA_STNT
# 7    2.0     2.2     2.2.1  SH_STA_STNT
# 8    2.0     2.2     2.2.1  SH_STA_STNT
# 9    2.0     2.2     2.2.1  SH_STA_STNT
# 10   2.0     2.2     2.2.1  SH_STA_STNT
#
#                                     SeriesDescription  GeoAreaCode  \
# 0   Proportion of children moderately or severely ...         96.0
# 1   Proportion of children moderately or severely ...        116.0
# 2   Proportion of children moderately or severely ...        360.0
# 3   Proportion of children moderately or severely ...        418.0
# 4   Proportion of children moderately or severely ...        458.0
# 5   Proportion of children moderately or severely ...        104.0
# ...

# %%
st = st.drop(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription', 'GeoAreaCode', 'Age', 'Location', 'Units', 'Reporting Type'], axis=1)
st
# Out:
#                          GeoAreaName  2000  2001  2002  2003  2004  2005  \
# 0                  Brunei Darussalam   NaN   NaN   NaN   NaN   NaN   NaN
# 1                           Cambodia  49.0   NaN   NaN   NaN   NaN  42.8
# 2                          Indonesia  42.4  41.6   NaN   NaN  28.6   NaN
# 3   Lao People's Democratic Republic  47.5   NaN   NaN   NaN   NaN   NaN
# 4                           Malaysia   NaN   NaN   NaN   NaN   NaN   NaN
# 5                            Myanmar  40.8   NaN   NaN  42.7   NaN   NaN
# 6                        Philippines   NaN   NaN   NaN  33.8   NaN   NaN
# 7                          Singapore   4.4   NaN   NaN   NaN   NaN   NaN
# 8                           Thailand   NaN   NaN   NaN   NaN   NaN   NaN
# 9                        Timor-Leste   NaN   NaN  55.7  54.8   NaN   NaN
# 10                          Viet Nam  43.2   NaN  37.5  35.4  33.7  33.2
#
#     2006  2007  2008  ...  2010  2011  2012  2013  2014  2015  2016  2017  \
# ...

# %%
st = st.set_index('GeoAreaName')
st = st.transpose()
st
# Out:
# GeoAreaName  Brunei Darussalam  Cambodia  Indonesia  \
# 2000                       NaN      49.0       42.4
# 2001                       NaN       NaN       41.6
# 2002                       NaN       NaN        NaN
# 2003                       NaN       NaN        NaN
# 2004                       NaN       NaN       28.6
# 2005                       NaN      42.8        NaN
# 2006                       NaN       NaN        NaN
# 2007                       NaN       NaN       40.1
# 2008                       NaN      39.5        NaN
# 2009                      19.7       NaN        NaN
# 2010                       NaN      39.8       39.2
# 2011                       NaN       NaN        NaN
# 2012                       NaN       NaN        NaN
# 2013                       NaN       NaN       36.4
# 2014                       NaN      32.4        NaN
# 2015                       NaN       NaN        NaN
# 2016                       NaN       NaN        NaN
# ...

# %%
st = st.interpolate()

# %%
sns.set(style="ticks")
g = sns.catplot(x="time", y="pulse", hue="kind", data=exercise)
plt.grid()  #just add this
plt.show()

# %%
sns.set(style='whitegrid', palette='Dark2')
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(10, 6), facecolor=facecolor)
sns.lineplot(data=top_st['Cambodia'],linewidth=5,marker="o", markevery=[0,4], markersize=12)
sns.lineplot(data=top_st['Indonesia'],linewidth=5,marker="o", markevery=[0, 3, 8], markersize=12)
sns.lineplot(data=top_st["Lao People's Democratic Republic"],linewidth=5,marker="o", markevery=[1, 5, 8], markersize=12)
sns.lineplot(data=top_st['Philippines'],linewidth=5,marker="o", markevery=[1, 3, 5, 8], markersize=12)

plt.grid(axis='x')
plt.show()
fig.savefig('stun.svg', transparent=True)

# %%
top_st = st[["Lao People's Democratic Republic", 'Cambodia', 'Indonesia', 'Philippines']].iloc[10:]
top_st
# Out:
# GeoAreaName  Lao People's Democratic Republic  Cambodia  Indonesia  \
# 2010                                   44.900     39.80  39.200000
# 2011                                   44.200     37.95  38.266667
# 2012                                   42.025     36.10  37.333333
# 2013                                   39.850     34.25  36.400000
# 2014                                   37.675     32.40  35.280000
# 2015                                   35.500     32.40  34.160000
# 2016                                   34.300     32.40  33.040000
# 2017                                   33.100     32.40  31.920000
# 2018                                   33.100     32.40  30.800000
# 2019                                   33.100     32.40  30.800000
#
# GeoAreaName  Philippines
# 2010           32.933333
# 2011           33.400000
# 2012           31.700000
# 2013           30.000000
# 2014           31.550000
# 2015           33.100000
# 2016           32.166667
# ...

# %%
top_st.index
# Out:
# Index(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019'],
#       dtype='object')

# %%
plt.plot(top_st,linewidth=4, marker='o', markersize=9)
plt.tight_layout()
plt.savefig('stunting.svg')
plt.show()

# %% [markdown]
# ## Food Severe

# %%
sv = pd.read_excel('/content/drive/MyDrive/SIC_2022_CELERA/212 kerawanan pangan sedang.xlsx')
sv.head(3)
# Out:
#    Goal  Target Indicator     SeriesCode  \
# 0   2.0     2.1     2.1.2  AG_PRD_FIESMS
# 1   2.0     2.1     2.1.2  AG_PRD_FIESMS
# 2   2.0     2.1     2.1.2  AG_PRD_FIESMS
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Prevalence of moderate or severe food insecuri...         96.0
# 1  Prevalence of moderate or severe food insecuri...        116.0
# 2  Prevalence of moderate or severe food insecuri...        360.0
#
#          GeoAreaName     Age  Freq  Location Observation Status  \
# 0  Brunei Darussalam  ALLAGE   NaN       NaN                  O
# 1           Cambodia  ALLAGE   NaN       NaN                  A
# 2          Indonesia  ALLAGE   NaN       NaN                  A
#
#   Reporting Type      Sex    Units  2015  2016  2017  2018  2019  2020
# 0              G  BOTHSEX  PERCENT   NaN   NaN   NaN   NaN   NaN   NaN
# 1              G  BOTHSEX  PERCENT  48.9  45.4  44.9  44.1  46.6  50.0
# ...

# %%
sv = sv.drop(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription', 'GeoAreaCode', 'Age', 'Freq', 'Location', 'Observation Status', 
              'Reporting Type', 'Sex', 'Units'], axis=1)
sv = sv.set_index('GeoAreaName')
sv = sv.transpose()
sv
# Out:
# GeoAreaName  Brunei Darussalam  Cambodia  Indonesia  \
# 2015                       NaN      48.9        6.0
# 2016                       NaN      45.4        7.3
# 2017                       NaN      44.9        7.6
# 2018                       NaN      44.1        7.0
# 2019                       NaN      46.6        6.2
# 2020                       NaN      50.0        6.0
#
# GeoAreaName  Lao People's Democratic Republic  Malaysia  Myanmar  Philippines  \
# 2015                                      NaN      17.4      NaN          NaN
# 2016                                      NaN      15.1      NaN          NaN
# 2017                                      NaN      15.1      NaN          NaN
# 2018                                      NaN      15.1      NaN         41.2
# 2019                                     29.4      14.9     22.2         42.7
# 2020                                     31.8      15.4     25.5         43.8
#
# ...

# %%
sv = sv.interpolate()
top_sv = sv[["Lao People's Democratic Republic", 'Cambodia', 'Indonesia', 'Philippines']]
top_sv
# Out:
# GeoAreaName  Lao People's Democratic Republic  Cambodia  Indonesia  \
# 2015                                      NaN      48.9        6.0
# 2016                                      NaN      45.4        7.3
# 2017                                      NaN      44.9        7.6
# 2018                                      NaN      44.1        7.0
# 2019                                     29.4      46.6        6.2
# 2020                                     31.8      50.0        6.0
#
# GeoAreaName  Philippines
# 2015                 NaN
# 2016                 NaN
# 2017                 NaN
# 2018                41.2
# 2019                42.7
# 2020                43.8

# %%
plt.plot(top_sv,marker='o',markerfacecolor='white')
plt.tight_layout()
#plt.savefig('kerawanan.svg')
plt.show()

# %%
un = pd.read_excel('/content/drive/MyDrive/SIC_2022_CELERA/211 kurang gizi.xlsx')
un.head(3)
# Out:
#    Goal  Target Indicator   SeriesCode                   SeriesDescription  \
# 0     2     2.1     2.1.1  SN_ITK_DEFC  Prevalence of undernourishment (%)
# 1     2     2.1     2.1.1  SN_ITK_DEFC  Prevalence of undernourishment (%)
# 2     2     2.1     2.1.1  SN_ITK_DEFC  Prevalence of undernourishment (%)
#
#    GeoAreaCode        GeoAreaName  Age Reporting Type  Sex  ...  2011  2012  \
# 0           96  Brunei Darussalam  NaN              G  NaN  ...  10.0   9.2
# 1          116           Cambodia  NaN              G  NaN  ...   9.7   9.5
# 2          360          Indonesia  NaN              G  NaN  ...  10.7   9.3
#
#    2013  2014  2015  2016  2017  2018  2019  2020
# 0   8.4   8.0   7.4   6.8   6.2   5.8   5.8   5.9
# 1   9.4   9.2   8.9   8.5   7.7   6.6   6.0   6.3
# 2   8.2   7.9   7.2   6.6   5.9   5.9   6.2   6.5
#
# [3 rows x 31 columns]

# %%
un = un.drop(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription', 'GeoAreaCode', 'Age', 'Sex', 'Units', 'Reporting Type'], axis=1)
un = un.set_index('GeoAreaName')
un = un.transpose()

# %%
top_un = un[['Thailand', 'Indonesia', 'Cambodia', 'Brunei Darussalam']].iloc[10:]
top_un
# Out:
# GeoAreaName Thailand Indonesia Cambodia Brunei Darussalam
# 2011             9.0      10.7      9.7              10.0
# 2012             8.8       9.3      9.5               9.2
# 2013             8.2       8.2      9.4               8.4
# 2014             7.8       7.9      9.2               8.0
# 2015             7.3       7.2      8.9               7.4
# 2016             7.5       6.6      8.5               6.8
# 2017             7.7       5.9      7.7               6.2
# 2018             7.8       5.9      6.6               5.8
# 2019             8.0       6.2      6.0               5.8
# 2020             8.8       6.5      6.3               5.9

# %%
plt.plot(top_un,linewidth=4, marker='o', markersize=9)
plt.tight_layout()
#plt.savefig('undernoursih.svg')
plt.show()

# %%
top_un
# Out:
# GeoAreaName Thailand Indonesia Cambodia Brunei Darussalam
# 2011             9.0      10.7      9.7              10.0
# 2012             8.8       9.3      9.5               9.2
# 2013             8.2       8.2      9.4               8.4
# 2014             7.8       7.9      9.2               8.0
# 2015             7.3       7.2      8.9               7.4
# 2016             7.5       6.6      8.5               6.8
# 2017             7.7       5.9      7.7               6.2
# 2018             7.8       5.9      6.6               5.8
# 2019             8.0       6.2      6.0               5.8
# 2020             8.8       6.5      6.3               5.9

# %%
sns.set(style='whitegrid')
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(10, 6), facecolor=facecolor)
sns.lineplot(data=top_un['Cambodia'], linewidth=5,marker="o",markersize=12)
sns.lineplot(data=top_un['Brunei Darussalam'], linewidth=5,marker="o", markersize=12)
sns.lineplot(data=top_un['Thailand'], linewidth=5,marker="o",markersize=12)
sns.lineplot(data=top_un['Indonesia'], linewidth=5,marker="o",markersize=12)

plt.ylim(5.6,11)
plt.grid(axis='x')
plt.show()
fig.savefig('undernou.svg', transparent=True)

# %%
un = un.drop(['Timor-Leste', 'Singapore'], axis=1)

# %%
un.loc['2020'].at['Malaysia'] = 2.4
un.loc['2019'].at['Myanmar'] = 2.4

# %%
plt.plot(un.iloc[10:],marker='o',markerfacecolor='white')
plt.tight_layout()
plt.show()

# %%
un.iloc[10:]
# Out:
# GeoAreaName Brunei Darussalam Cambodia Indonesia  \
# 2011                     10.0      9.7      10.7
# 2012                      9.2      9.5       9.3
# 2013                      8.4      9.4       8.2
# 2014                      8.0      9.2       7.9
# 2015                      7.4      8.9       7.2
# 2016                      6.8      8.5       6.6
# 2017                      6.2      7.7       5.9
# 2018                      5.8      6.6       5.9
# 2019                      5.8      6.0       6.2
# 2020                      5.9      6.3       6.5
#
# GeoAreaName Lao People's Democratic Republic Malaysia Myanmar Philippines  \
# 2011                                    12.8      3.3     7.8        12.4
# 2012                                    11.3      3.3     7.1        12.1
# 2013                                    10.0      3.5     6.1        11.6
# 2014                                     8.0      3.6     5.1        11.1
# ...
